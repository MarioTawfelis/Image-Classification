# %% [markdown]
# # Image Classification - Data Cleaning

# %%
# Installing requirements
! pip install -r requirements.txt
# Out:
# Collecting PyWavelets==0.5.2
#   Using cached PyWavelets-0.5.2.tar.gz (4.4 MB)
#   Preparing metadata (setup.py) ... done
# Collecting opencv-python==4.5.4.60
#   Downloading opencv_python-4.5.4.60-cp38-cp38-macosx_10_15_x86_64.whl (45.9 MB)
#      |████████████████████████████████| 45.9 MB 6.3 MB/s
# Collecting seaborn==0.8.1
#   Downloading seaborn-0.8.1.tar.gz (178 kB)
#      |████████████████████████████████| 178 kB 7.0 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.9.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from PyWavelets==0.5.2->-r requirements.txt (line 1)) (1.18.1)
# Building wheels for collected packages: PyWavelets, seaborn
#   Building wheel for PyWavelets (setup.py) ... done
#   Created wheel for PyWavelets: filename=PyWavelets-0.5.2-cp38-cp38-macosx_10_9_x86_64.whl size=4251596 sha256=5682671e1dece990df154659b4544aa693e5c2d12596f5df4eee446c3bdba501
#   Stored in directory: /Users/mario/Library/Caches/pip/wheels/8f/e7/f7/21e83281c6f16c46b10400b77a7f730409827cd6329e1df217
#   Building wheel for seaborn (setup.py) ... done
#   Created wheel for seaborn: filename=seaborn-0.8.1-py3-none-any.whl size=184833 sha256=69f16a482d966cfa2355150f5f4f9bc7d1aa71f3ec44da7fe115f1c6ac0fbab3
#   Stored in directory: /Users/mario/Library/Caches/pip/wheels/18/48/9b/39ac10dbe8ed3a4883283aed441a765239b3cc7c94ed5a2040
# Successfully built PyWavelets seaborn
# Installing collected packages: seaborn, PyWavelets, opencv-python
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.10.1
#     Uninstalling seaborn-0.10.1:
#       Successfully uninstalled seaborn-0.10.1
# Successfully installed PyWavelets-0.5.2 opencv-python-4.5.4.60 seaborn-0.8.1

# %%
# Importing required packages
import numpy as np
import cv2 as cv
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Test

# %%
# Read an image
img = cv.imread('./datasets/beyonce/0f80c7cb9f.jpg')

# View image dimentions (Length, Width, RGB)
img.shape
# Out:
# (2400, 2000, 3)

# %%
# View image
plt.imshow(img)

# %%
# Convert image to grayscale
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# View image dimentions (Length, Width, RGB)
img_gray.shape
# Out:
# (2400, 2000)

# %%
# View image
plt.imshow(img_gray, cmap='gray')
